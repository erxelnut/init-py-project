# %%
import pandas as pd

# %%
import numpy as np

# %%
a = np.array([1,0,1])
b = np.array([[1],[0],[1]])

# %%
a*b
# Out:
# array([[1, 0, 1],
#        [0, 0, 0],
#        [1, 0, 1]])

# %%
b*a
# Out:
# array([[1, 0, 1],
#        [0, 0, 0],
#        [1, 0, 1]])

# %%
np.dot(a,b)
# Out:
# array([2])

# %%
#np.cross(a,b)
#get error
